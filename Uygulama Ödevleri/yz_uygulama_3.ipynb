# %%
print("Uygulama - 3 Soru 1")

try:
    deger = int(input("Sayi giriniz: "))
except:
    print("Lutfen sayi giriniz!")

i=1
while i<11:
    print(deger*i)
    i+=1

# %%
print("Uygulama - 3 Soru 2")

try:
    sayi = int(input("Sayi giriniz: "))
except:
    print("Lutfen sayi giriniz!")

a=0
for i in str(sayi):
   a+=1
print("Girilen sayi {} bamaklidir.".format(a))

# %%
print("Uygulama - 3 Soru 3")

sayısalDeğerler = [12, 15, 32, 42, 55, 75, 122, 132, 150, 180, 200]
alfa=[]
i=0
while i < len(sayısalDeğerler):
    if(sayısalDeğerler[i]%5==0 and sayısalDeğerler[i]<151):
        alfa.append(sayısalDeğerler[i]) 
    i+=1
    
print(alfa)

alfa=[]
for i in sayısalDeğerler:
    if (i<151 and i%5==0):
        alfa.append(i)

print(alfa)

# %%
print("Uygulama - 3 Soru 4")

try:
    a = int(input("a Sayisini giriniz: "))
    b = int(input("b Sayisini giriniz: "))
    c = int(input("c Sayisini giriniz: "))
except:
    print("Lutfen sayi giriniz!")

alfa = []
k = a
try:
    if (a < b):
        while k<=b:
            if(k%c==0):
                alfa.append(k)
            k+=1

    print(alfa)
except:
    print("Muhtemelen a sayisi b sayisindan kucuk degil.")

# %%
print("Uygulama - 3 Soru 5")

for i in range(1,100):
  print(i, "-", 100-i)
# Out:
# Uygulama - 3 Soru 5
# 1 - 99
# 2 - 98
# 3 - 97
# 4 - 96
# 5 - 95
# 6 - 94
# 7 - 93
# 8 - 92
# 9 - 91
# 10 - 90
# 11 - 89
# 12 - 88
# 13 - 87
# 14 - 86
# 15 - 85
# 16 - 84
# 17 - 83
# 18 - 82
# 19 - 81
# 20 - 80
# 21 - 79
# 22 - 78
# 23 - 77
# 24 - 76
# 25 - 75
# 26 - 74
# 27 - 73
# 28 - 72
# 29 - 71
# 30 - 70
# 31 - 69
# 32 - 68
# 33 - 67
# 34 - 66
# 35 - 65
# 36 - 64
# 37 - 63
# 38 - 62
# 39 - 61
# 40 - 60
# 41 - 59
# 42 - 58
# 43 - 57
# 44 - 56
# 45 - 55
# 46 - 54
# 47 - 53
# 48 - 52
# 49 - 51
# 50 - 50
# 51 - 49
# 52 - 48
# 53 - 47
# 54 - 46
# 55 - 45
# 56 - 44
# 57 - 43
# 58 - 42
# 59 - 41
# 60 - 40
# 61 - 39
# 62 - 38
# 63 - 37
# 64 - 36
# 65 - 35
# 66 - 34
# 67 - 33
# 68 - 32
# 69 - 31
# 70 - 30
# 71 - 29
# 72 - 28
# 73 - 27
# 74 - 26
# 75 - 25
# 76 - 24
# 77 - 23
# 78 - 22
# 79 - 21
# 80 - 20
# 81 - 19
# 82 - 18
# 83 - 17
# 84 - 16
# 85 - 15
# 86 - 14
# 87 - 13
# 88 - 12
# 89 - 11
# 90 - 10
# 91 - 9
# 92 - 8
# 93 - 7
# 94 - 6
# 95 - 5
# 96 - 4
# 97 - 3
# 98 - 2
# 99 - 1

# %%
print("Uygulama - 3 Soru 6")

ip = input("ip adresini giriniz. Ex: 192 168 1 1\n")
spl = [int(i) for i in ip.split(' ')]

for i in range(1,6):
  spl[3]+=1
  if spl[3] % 256 != 0 and spl[3]<256 :
    print(spl)
  else:
    spl[3] = spl[3] % 256
    spl[2]= spl[2] % 256
    spl[2]+=1
    if (spl[2]%256!=0) and spl[2]<256:
      print(spl)
    else:
      spl[2] = spl[2] % 256
      spl[1]= spl[1] % 256
      spl[1]+=1
      if spl[1]%256!=0 and spl[1]<256:
        print(spl)
      else:
        spl[1] = spl[1] % 256
        spl[0]= spl[0] % 256
        spl[0]+=1
        if spl[0]%256!=0 and spl[0]<256:
          print(spl)
        else:
          spl[0] = spl[0] % 256
          spl[0]+=1
          print(spl)
